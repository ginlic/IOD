# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
df = pd.read_csv("../../DATA/Employee-attrition.csv")
pd.set_option('display.max_columns', 50)

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49648          Layoff   Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49652          Layoff   Involuntary         2014  TERMINATED        STORES

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find the shape of the dataframe

# %%
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find the data types of the dataframe

# %%
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find the number of data types in the dataframe
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore the difference.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 6.8+ MB

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of the `job_title` column

# %%
df['job_title'].unique()
# Out:
# array(['CEO', 'VP Stores', 'Legal Counsel', 'VP Human Resources',
#        'VP Finance', 'Exec Assistant, VP Stores',
#        'Exec Assistant, Legal Counsel', 'CHief Information Officer',
#        'Store Manager', 'Meats Manager',
#        'Exec Assistant, Human Resources', 'Exec Assistant, Finance',
#        'Director, Recruitment', 'Director, Training',
#        'Director, Labor Relations', 'Director, HR Technology',
#        'Director, Employee Records', 'Director, Compensation',
#        'Corporate Lawyer', 'Produce Manager',
#        'Director, Accounts Receivable', 'Bakery Manager',
#        'Systems Analyst', 'Director, Accounts Payable', 'Director, Audit',
#        'Director, Accounting', 'Director, Investments', 'Dairy Person',
#        'Recruiter', 'Processed Foods Manager', 'Customer Service Manager',
#        'Trainer', 'Meat Cutter', 'Labor Relations Analyst',
#        'Dairy Manager', 'HRIS Analyst', 'Benefits Admin',
#        'Compensation Analyst', 'Accounts Receiveable Clerk',
#        'Accounts Payable Clerk', 'Baker', 'Auditor', 'Accounting Clerk',
#        'Investment Analyst', 'Produce Clerk', 'Shelf Stocker', 'Cashier'],
#       dtype=object)

# %% [markdown]
# #### 2.B Find how many rows are in each job title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Systems Analyst                      20
# Investment Analyst                   20
# Compensation Analyst                 20
# Corporate Lawyer                     17
# CEO                                  10
# Exec Assistant, VP Stores            10
# Legal Counsel                        10
# VP Stores                            10
# VP Human Resources                   10
# VP Finance                           10
# Director, Recruitment                10
# Exec Assistant, Finance              10
# Exec Assistant, Human Resources      10
# CHief Information Officer            10
# Exec Assistant, Legal Counsel        10
# Director, Accounts Payable            9
# Director, Accounts Receivable         9
# Director, Employee Records            9
# Director, HR Technology               9
# Dairy Manager                         9
# Director, Accounting                  9
# Director, Investments                 4
# Director, Labor Relations             4
# Director, Compensation                4
# Director, Audit                       4
# Director, Training                    4
# Name: count, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write a function to count the number of rows
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
def row_count(dataframe):
    number_of_rows = dataframe.shape[0]
    return number_of_rows

# %%
row_count(df)
# Out:
# 49653

# %% [markdown]
# #### 2.D Describe `age`
#
# Find the count, mean, std, min, max of the column 'age'

# %%
df[('age')].agg(['count','mean', 'std', min, max])
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe all numeric columns of the dataframe
#
# Find the count, mean, std, min, max of all columns of the dataframe

# %%
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Make the index meaningful by making `EmployeeID` the index

# %%
df.set_index('EmployeeID', inplace=True)
# df.reset_index(inplace=True)
df.head()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 3.A Find a specific row using the index

# %%
df.loc[1318]
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2012 0:00      1/3/1954        8/28/1989
# 1318        12/31/2013 0:00      1/3/1954        8/28/1989
# 1318        12/31/2014 0:00      1/3/1954        8/28/1989
# 1318        12/31/2015 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# 1318                  1/1/1900   57                 22  Vancouver
# 1318                  1/1/1900   58                 23  Vancouver
# 1318                  1/1/1900   59                 24  Vancouver
# 1318                  1/1/1900   60                 25  Vancouver
# 1318                  1/1/1900   61                 26  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2011  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2012  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2013  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2014  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2015  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 3.B Sort the dataframe using the index

# %%
df.sort_values("EmployeeID", ascending=False)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8335        12/31/2014 0:00    12/28/1994       12/10/2013
# ...                     ...           ...              ...
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 8336                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   20                  1  Vancouver
# 8336                  1/1/1900   19                  0  Vancouver
# 8335                  1/1/1900   21                  2  Vancouver
# 8335                  1/1/1900   20                  1  Vancouver
# ...                        ...  ...                ...        ...
# 1318                  1/1/1900   57                 22  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   52                 17  Vancouver
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
# 8335                 Dairy  Dairy Person          35            F      Female
# 8335                 Dairy  Dairy Person          35            F      Female
# ...                    ...           ...         ...          ...         ...
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 8336        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2014  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8335        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8335        Not Applicable  Not Applicable         2014  ACTIVE        STORES
# ...                    ...             ...          ...     ...           ...
# 1318        Not Applicable  Not Applicable         2011  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.C [BONUS] Sort the dataframe using `age`

# %%
df.sort_values("age", inplace=True)
df
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8325        12/31/2013 0:00     12/7/1994       11/29/2013
# 8253        12/31/2013 0:00     5/15/1994        8/12/2013
# 8252        12/31/2013 0:00     5/10/1994         8/9/2013
# 8251        12/31/2013 0:00      5/7/1994         8/7/2013
# 8250        12/31/2013 0:00     4/26/1994         8/2/2013
# ...                     ...           ...              ...
# 3262          8/1/2008 0:00     8/23/1943        2/28/1995
# 3248          8/1/2008 0:00     8/14/1943        2/19/1995
# 4948          7/1/2013 0:00      7/9/1948        1/14/2000
# 3356         11/1/2008 0:00    11/18/1943        5/26/1995
# 4138          2/1/2011 0:00     2/12/1946        8/20/1997
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 8325                  1/1/1900   19                  0        Cranbrook
# 8253                  1/1/1900   19                  0  North Vancouver
# 8252                  1/1/1900   19                  0         Victoria
# 8251                  1/1/1900   19                  0        Vancouver
# 8250                  1/1/1900   19                  0          Burnaby
# ...                        ...  ...                ...              ...
# 3262                 8/23/2008   65                 13          Nanaimo
# 3248                 8/14/2008   65                 13        Vancouver
# 4948                  7/9/2013   65                 13          Burnaby
# 3356                11/18/2008   65                 13          Nanaimo
# 4138                 2/12/2011   65                 13           Surrey
#
#              department_name      job_title  store_name gender_short  \
# EmployeeID
# 8325        Customer Service        Cashier           8            M
# 8253        Customer Service        Cashier          22            F
# 8252        Customer Service        Cashier          46            F
# 8251        Customer Service        Cashier          44            F
# 8250                   Dairy   Dairy Person           5            F
# ...                      ...            ...         ...          ...
# 3262                   Meats    Meat Cutter          18            F
# 3248                   Dairy   Dairy Person          35            F
# 4948                 Produce  Produce Clerk           5            F
# 3356                   Meats    Meat Cutter          18            F
# 4138                 Produce  Produce Clerk          31            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 8325              Male  Not Applicable  Not Applicable         2013
# 8253            Female  Not Applicable  Not Applicable         2013
# 8252            Female  Not Applicable  Not Applicable         2013
# 8251            Female  Not Applicable  Not Applicable         2013
# 8250            Female  Not Applicable  Not Applicable         2013
# ...                ...             ...             ...          ...
# 3262            Female      Retirement       Voluntary         2008
# 3248            Female      Retirement       Voluntary         2008
# 4948            Female      Retirement       Voluntary         2013
# 3356            Female      Retirement       Voluntary         2008
# 4138            Female      Retirement       Voluntary         2011
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 8325            ACTIVE        STORES
# 8253            ACTIVE        STORES
# 8252            ACTIVE        STORES
# 8251            ACTIVE        STORES
# 8250            ACTIVE        STORES
# ...                ...           ...
# 3262        TERMINATED        STORES
# 3248        TERMINATED        STORES
# 4948        TERMINATED        STORES
# 3356        TERMINATED        STORES
# 4138        TERMINATED        STORES
#
# [49653 rows x 17 columns]

# %% [markdown]
# #### 3.D [BONUS] Using `sample` select any row

# %%
df.sample(20)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 2694        12/31/2006 0:00     8/14/1956         9/4/1993
# 2248        12/31/2012 0:00      3/1/1954        5/19/1992
# 7809        12/31/2012 0:00    11/14/1990        10/7/2011
# 1395          5/1/2014 0:00     5/11/1949        11/4/1989
# 6648        12/31/2007 0:00    12/30/1981        1/29/2007
# 2896        12/31/2007 0:00      8/4/1957        3/11/1994
# 6546        12/31/2013 0:00     3/12/1981        8/28/2006
# 7058        12/31/2009 0:00     3/20/1985       10/11/2008
# 6030        12/31/2014 0:00     3/15/1977        7/19/2004
# 5016        12/31/2006 0:00      1/1/1969        3/20/2000
# 2747          4/1/2007 0:00     4/24/1942       10/30/1993
# 6713        12/31/2009 0:00     6/21/1982         5/1/2007
# 7429        12/31/2010 0:00     2/12/1988        4/24/2010
# 5885        12/31/2014 0:00     12/4/1975       11/15/2003
# 1757        12/31/2011 0:00      5/5/1951       11/22/1990
# 5189        12/31/2007 0:00     1/31/1970       10/15/2000
# 6891        12/31/2013 0:00     12/3/1983         2/5/2008
# 7634        12/31/2015 0:00     7/26/1989        1/28/2011
# 2922        12/31/2008 0:00     9/26/1957         4/8/1994
# 4251        12/31/2013 0:00     9/25/1964       12/17/1997
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 2694                  1/1/1900   50                 13          Kelowna
# 2248                  1/1/1900   58                 20          Nanaimo
# 7809                  1/1/1900   22                  1           Surrey
# 1395                 5/11/2014   65                 24        Vancouver
# 6648                  1/1/1900   26                  0  New Westminster
# 2896                  1/1/1900   50                 13        Vancouver
# 6546                  1/1/1900   32                  7     Fort St John
# 7058                  1/1/1900   24                  1          Nanaimo
# 6030                  1/1/1900   37                 10          Nanaimo
# 5016                  1/1/1900   37                  6  North Vancouver
# 2747                 4/24/2007   65                 13          Burnaby
# 6713                 6/21/2012   27                  2           Nelson
# 7429                  1/1/1900   22                  0          Burnaby
# 5885                  1/1/1900   39                 11   Port Coquitlam
# 1757                  1/1/1900   60                 21          Nanaimo
# 5189                  1/1/1900   37                  7  New Westminster
# 6891                  1/1/1900   30                  5       Abbotsford
# 7634                  1/1/1900   26                  4  North Vancouver
# 2922                  1/1/1900   51                 14          Nanaimo
# 4251                  1/1/1900   49                 16        Vancouver
#
#              department_name     job_title  store_name gender_short  \
# EmployeeID
# 2694                   Meats   Meat Cutter          16            M
# 2248                   Meats   Meat Cutter          18            M
# 7809        Customer Service       Cashier          31            F
# 1395             Recruitment     Recruiter          35            F
# 6648                   Dairy  Dairy Person          21            M
# 2896        Customer Service       Cashier          41            M
# 6546                   Dairy  Dairy Person          12            M
# 7058        Customer Service       Cashier          18            F
# 6030                   Dairy  Dairy Person          18            F
# 5016                  Bakery         Baker          22            M
# 2747                   Meats   Meat Cutter           5            F
# 6713                  Bakery         Baker          19            F
# 7429                   Dairy  Dairy Person           5            M
# 5885        Customer Service       Cashier          25            M
# 1757                   Meats   Meat Cutter          18            F
# 5189                  Bakery         Baker          21            F
# 6891                  Bakery         Baker           1            F
# 7634        Customer Service       Cashier          22            F
# 2922                   Meats   Meat Cutter          18            M
# 4251                  Bakery         Baker          42            M
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 2694              Male  Not Applicable  Not Applicable         2006
# 2248              Male  Not Applicable  Not Applicable         2012
# 7809            Female  Not Applicable  Not Applicable         2012
# 1395            Female      Retirement       Voluntary         2014
# 6648              Male  Not Applicable  Not Applicable         2007
# 2896              Male  Not Applicable  Not Applicable         2007
# 6546              Male  Not Applicable  Not Applicable         2013
# 7058            Female  Not Applicable  Not Applicable         2009
# 6030            Female  Not Applicable  Not Applicable         2014
# 5016              Male  Not Applicable  Not Applicable         2006
# 2747            Female      Retirement       Voluntary         2007
# 6713            Female  Not Applicable  Not Applicable         2009
# 7429              Male  Not Applicable  Not Applicable         2010
# 5885              Male  Not Applicable  Not Applicable         2014
# 1757            Female  Not Applicable  Not Applicable         2011
# 5189            Female  Not Applicable  Not Applicable         2007
# 6891            Female  Not Applicable  Not Applicable         2013
# 7634            Female  Not Applicable  Not Applicable         2015
# 2922              Male  Not Applicable  Not Applicable         2008
# 4251              Male  Not Applicable  Not Applicable         2013
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 2694            ACTIVE        STORES
# 2248            ACTIVE        STORES
# 7809            ACTIVE        STORES
# 1395        TERMINATED    HEADOFFICE
# 6648            ACTIVE        STORES
# 2896            ACTIVE        STORES
# 6546            ACTIVE        STORES
# 7058            ACTIVE        STORES
# 6030            ACTIVE        STORES
# 5016            ACTIVE        STORES
# 2747        TERMINATED        STORES
# 6713            ACTIVE        STORES
# 7429            ACTIVE        STORES
# 5885            ACTIVE        STORES
# 1757            ACTIVE        STORES
# 5189            ACTIVE        STORES
# 6891            ACTIVE        STORES
# 7634            ACTIVE        STORES
# 2922            ACTIVE        STORES
# 4251            ACTIVE        STORES

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find rows Where `job_title` is CEO

# %%
#df.query("job_title=='CEO'")
df[df['job_title']=='CEO']
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2012 0:00      1/3/1954        8/28/1989
# 1318        12/31/2013 0:00      1/3/1954        8/28/1989
# 1318        12/31/2014 0:00      1/3/1954        8/28/1989
# 1318        12/31/2015 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# 1318                  1/1/1900   57                 22  Vancouver
# 1318                  1/1/1900   58                 23  Vancouver
# 1318                  1/1/1900   59                 24  Vancouver
# 1318                  1/1/1900   60                 25  Vancouver
# 1318                  1/1/1900   61                 26  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2011  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2012  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2013  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2014  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2015  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 4.B Group by `age` and find how many there are of each age

# %%
df.groupby('age')['age'].value_counts()
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# Name: count, dtype: int64

# %% [markdown]
# # 5. Visualisation
#
#
# #### 5.A Plot a histogram of `age`

# %%
plt.hist(df['age'], bins=20)
plt.xlabel('Age in years')
plt.ylabel('Frequency')
plt.title('Age Histogram')
plt.show()

# %% [markdown]
# #### 5.B BoxPlot of `age`

# %%
plt.boxplot(df['age'])
plt.title('Age BoxPlot')
plt.xlabel('Age Column')
plt.ylabel('Age in years')
plt.show()

# %% [markdown]
# #### 5.C Create a scatterplot of `age` and `length_of_service`

# %%
plt.scatter(df['age'], df['length_of_service'], color ='orange', alpha=0.5)
plt.xlabel('Age in years')
plt.ylabel('Length of Service')
plt.title('Age vs Length of service')
plt.show()

# %% [markdown]
# #### 5.D Print a statistical summary of `age`

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
